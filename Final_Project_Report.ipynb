# %% [markdown]
# # Project Final Report
#
# ### Due: Midnight on April 27th (2-hour grace period) — 50 points
#
# ### No late submissions will be accepted.
#
#
# ## Overview
#
# Your final submission consists of **two components**:
#
#
# ### 1. Team Final Report Notebook [50 pts]
#
# Complete all sections of this notebook to document your final decisions, results, and broader context.
#
# You will write a **technical report** following standard conventions. Useful references include:
# - [CMU guide to structure](https://www.stat.cmu.edu/~brian/701/notes/paper-structure.pdf)
# - [Data science report example](https://www.projectpro.io/article/data-science-project-report/620)
# - The Checklist in this week’s Blackboard Lesson (aligned with HOML)
#
# Your audience is **technically literate but unfamiliar with your work**—for example, your manager or other data scientists. Your report should be clear, precise, and well-organized, combining explanation, visualizations, and interpretation.
#
# This Final Report is distinct from Milestone 2:
#
# - **Milestone 2** serves as a repository of your working code and experiments
# - **This Final Report** presents a clear, structured summary of your project for a professional audience
#
# > **Important:**
# > - Do **not** assume that readers of this report are familiar with Milestone 2. Your report should stand on its own.
# > - Do not include full code or code cells in this notebook. All code was submitted in Milestone 2. This report should focus on explanation, results, and interpretation.
# > - **Do not add, delete, or move cells in this notebook.** Each answer must be written entirely within its assigned Markdown cell.
# > - All answers should be inserted directly under the appropriate `Answer:` prompt. Delete the sentence "Replace this sentence with your answer" and replace it with your response.
# > - You may use any appropriate Markdown formatting (paragraphs, lists, tables, inserted graphics, LaTeX, etc.).
# > - Submit this notebook as a group via your team leader’s Gradescope account.
#
#
# ### 2. Individual Assessment [0 points]
#
# Each team member must **individually** complete the Final Project Individual Assessment Form (similar to Milestone 1), sign it, and upload it via their own Gradescope account.
#
# **Due:** May 5th @ 2:00 AM
#
#
#
# ## Submission Checklist
#
# - Final Report Notebook — submitted by team leader
# - Individual Assessment Form — submitted by each team member

# %% [markdown]
# ## 1. Executive Summary [4 pts]
#
# Write a 300–400 word executive summary for a **non-technical audience**, such as business stakeholders in a real estate company.
#
# Your summary should explain:
# - the objective of the project
# - key insights about the data
# - the most important findings, including a plain-language description of model performance
# - a clear recommendation or takeaway
#
# Avoid technical detail and jargon. Focus on what matters and why.
#
# **1.1 Answer:**
# The goal of this project was to develop a reliable way to estimate the tax value of residential properties using information already available in Zillow’s housing dataset. By understanding which home characteristics most strongly influence value, the company can make more informed decisions about pricing, acquisitions, and market strategy.
#
# The dataset included a wide range of property details, such as number of bathrooms, year built, and finished square footage, but it also came with challenges. Many records were incomplete, some fields were inconsistent, and a small number of extreme values distorted the overall picture. A significant portion of the work involved cleaning the data, resolving missing or inaccurate entries, and ensuring that the information used for modeling reflected real, typical properties rather than rare outliers.
#
# Throughout the project, we explored a variety of ways to enhance the dataset and test different modeling approaches. This included experimenting with additional derived features and more complex modeling techniques. However, the most important insight was that simpler turned out to be better. After comparing multiple approaches, the model that performed best was a straightforward linear model built only on the original property attributes, once those attributes were properly cleaned and prepared.
#
# This finding underscores a key lesson: high‑quality, well‑prepared data often matters more than adding complexity. In this case, the original features already contained the essential signals needed to make strong predictions, and additional layers of manipulation did not improve accuracy.
#
# The main takeaway for stakeholders is that the company can confidently rely on a clean, streamlined set of property characteristics to estimate tax values. Investing in consistent, accurate data collection will likely yield greater returns than pursuing increasingly complex modeling techniques. A simple, transparent model not only performs well but is also easier to maintain, explain, and integrate into business workflows.

# %% [markdown]
# ## 2. Introduction [3 pts]
#
# Introduce the topic, context, and goals of your project.
#
# You may imagine that this project was completed for a **real estate company with a small in-house data science team**.
#
# Include all of the following:
#
# - Clearly introduce the topic and context of your project
# - Describe the problem you are addressing (the problem statement) and the overall motivation for solving it
# - Clearly state the objectives and goals of your analysis (as different from the motivation)
#
# **2.1 Answer:**
# This project focuses on building a model that can estimate the tax value of a home using readily available property characteristics. For a real estate company, having a dependable way to understand property value is essential. Tax value, in particular, offers a stable reference point that supports pricing decisions, investment planning, and communication with clients. It also helps homeowners and buyers better understand what a property is worth and how it compares to others in the market.
#
# The problem we are addressing is the difficulty of consistently and accurately estimating tax values across a large and diverse set of properties. While tax assessments exist, they can be outdated, inconsistent, or incomplete. For a company that relies on accurate valuations, whether for acquisitions, pricing strategy, or market analysis, having an internal, data‑driven method provides a meaningful advantage. The motivation behind this work is to give the business a reliable, scalable tool that supports decision‑making and reduces uncertainty.
#
# The objective of the analysis is more specific: to use the Zillow dataset to develop a predictive model that estimates tax value based on property attributes such as size, age, and square footage of the house. This includes preparing the data, identifying which features are most informative, and evaluating different modeling approaches to determine which one provides the most accurate and practical predictions.

# %% [markdown]
# ## 3. Data Description [3 pts]
#
# Describe the dataset used in your analysis.
#
# Include:
# - the source of the dataset
# - the number of observations (samples) and features
# - the types of variables
# - the target variable
# - missing values or other important issues in the raw data
#
# **3.1 Answer:**
# The dataset used in this analysis comes from Zillow’s public housing data, which provides detailed information about residential properties. The dataset contains 77,613 observations, with each row representing a single property. In total, there are 55 features, including a unique property identifier, physical characteristics of the home, and various tax‑related attributes.
#
# The variables in the dataset include a mix of integers, floats, and string‑based categorical fields. Examples include the number of bathrooms, finished square footage, year built, and lot size. The target variable for this project is the property’s tax value, recorded as a continuous numeric value representing the assessed dollar amount.
#
# A major issue with the raw data is the presence of substantial missing values across many features. Several columns had missing data for more than 70,000 properties, making them unusable for modeling. Examples include:
#
# - buildingclasstypeid (77,598 missing)
# - finishedsquarefeet13 (77,571 missing)
# - basementsqft (77,563 missing)
# - storytypeid (77,563 missing)
# - yardbuildingsqft26 (77,543 missing)
# - fireplaceflag (77,441 missing)
#
# Because these features were missing for nearly the entire dataset, they were removed during preprocessing. In addition to missing values, the dataset also contained 199 duplicate rows, which were dropped to ensure data quality.
#
# Overall, while the dataset provides a rich set of property attributes, the high number of missing values and inconsistencies required significant cleaning before any modeling could be performed.

# %% [markdown]
# ## 4. Methodology (What you did, and why) [20 pts]
#
# Focus on the **process and your reasoning**, not the results.
#
# Note: Each subsection (e.g., 4.1, 4.2, etc.) must be answered in its own Markdown cell.  Each subsection is worth 5 points.

# %% [markdown]
# ### 4.1 Analytical Framework
#
# Describe your overall approach.
#
# Include:
# - your overall framework
# - use of validation curves
# - choice of MAE or RMSE (as appropriate) as the primary error metric
#
# **4.1 Answer:**
# Our analytical choices followed a supervised machine learning approach to predict housing prices using the Zillow dataset. The workflow consisted of data preprocessing, exploratory data analysis (EDA), feature engineering, model training, and evaluation. The goal was to build a model that could accurately estimate home values while maintaining strong generalization performance.
#
# We split the dataset into training and testing sets and used cross-validation to evaluate model performance and stability over different subsets of the data. This ensured that performance results were not dependent on a single split and helped reduced overfitting.
#
# We also used validation curves to see how model complexity impacted performance. By analyzing the training and validation error across parameters, we discovered what the optimal levels of complexity were that minimized overfitting.
#
# We chose Root Mean Squared Error (RMSE) as the primary evaluation metric because housing price prediction is highly sensitive to large errors. We tried the Mean Absolute Error (MAE) for interpretability, but we used RMSE for final model comparison.

# %% [markdown]
# ### 4.2 Data Cleaning and Preprocessing
#
# Describe how you prepared the data.
#
# Include:
# - issues in the raw data
# - handling of missing values, outliers, inconsistencies
# - key decisions and why
# - what worked and what did not work
#
# **4.2 Answer:**
# The Zillow dataset required a lot of preprocessing due to the amount of missing values, inconsistent data formats, and the extreme outliers it had. Many features contained missing values, specifically property related features like lot size, number of bathrooms, and tax related variables.
#
# We handled numerical missing values by using the median value method to reduce the impact of skewed distributions. Features that had too many missing values or were not relevant were removed to avoid introducing noise.
#
# Outliers played a big role in this analysis. Seeing as housing price data often includes extreme values, outliers were expected, so they were not removed. We retained values that appeared valid and removed the ones that distorted model performance.
#
# We also made sure that the feautre formats were standard, the data types were consistent, and removed duplicate or redundant columns. We applied normalization to ensure that all feature contributed appropriately during training.
#
# Some preprocessing strategies, such as dropping rows with missing values, resulted in significant data loss and were not effective for our overall analysis.

# %% [markdown]
# ### 4.3 Feature Engineering
#
# Describe your feature engineering.
#
# Include:
# - transformations or new features
# - why you created them
# - which were useful or not useful
# - what worked and what did not work
#
# **4.3 Answer:**
# Feature engineering had a critical role in improving model performance by enhancing the representation of housing characteristics. We created and transformed features based on domain knowledge of real estate pricing and patterns seen in EDA.
#
# One of our key transformations was log transforming the target variable (housing price) to reduce skewness and improve model stability. More transformations were applied to highly skewed features such as lot size and tax values.
#
# We also created dervied features to see meaningful realtionships. For example, combining variables like total rooms or calculating ratios (such as price per square foot) helped better represent property value. We noticed that location based features were particularly improtant, as geographic factors strongly influenced housing prices.
#
# Feature importance from models such as Random Forest was used to evaluate the usefulness of variables. This allowed us to identify which features contributed most to predictions and remove those with minimal impact.
#
# Some engineered features did not improve performance, and we excluded them from the final model. Overly complex combinations introduced noise rather than improving predictions. The most effective features were those that captured intuitive relationships in the housing market without adding unnecessary noise.

# %% [markdown]
# ### 4.4 Model Selection
#
# Describe how you selected your model.
#
# Include:
# - models you tried and why
# - how you evaluated generalization
# - hyperparameter tuning
# - how you chose the final model
#
# **4.4 Answer:**
# We evaluated several models to determine the best approach for predicting housing prices, including linear regression as a baseline and more advanced mdoels such as Random Forest. Linear Regression was chosen for its simplicity and interpretability, while Random Forest was used to capture nonlinear relationships and interactions between features.
#
# Model performance was evaluated using cross-validation to make sure that generalization was possible across different subsets of the data. RMSE was used as the primary metric for comparison, since it emphasizes larger prediciton errors that are important for housing price estimation.
#
# Hyperparameter tuning was done using grid search and validation curves. For the Random Forest model, we tuned parameters such as the number of trees, maximum depth, and minimum samples per split. Validation curves helped identify optimal parameter values by showing us where validation error stabilized without overfitting the model.
#
# We chose the final model based on a combination of predictive performance and stability. Linear Regression remained outperforming Random Forest overall, despite both being useful for observations. Linear Regression achieved the lowest mean cross-validation MAE and also outperformed the tuned models on the held-out test set.
#
# Overall, our selected model acheived strong predictive accuracy while maintaining good generalization, making it good for estimating housing prices in the Zillow dataset.

# %% [markdown]
# ## 5. Results and Evaluation (What you found, and how well it worked) [16 pts]
#
# Focus on **results, evidence, and interpretation**.
#
# Note: Each subsection (e.g., 5.1, 5.2, etc.) must be answered in its own Markdown cell.

# %% [markdown]
# ### 5.1 Model Performance (6 points)
#
# Briefly interpret what your metrics mean in practical terms.
#
# Include:
# - key metrics (e.g., RMSE, $R^2$)
# - comparison across models
# - comparison of training vs validation/test performance
#
# **5.1 Answer:**
# After evaluating multiple models, including Linear Regression, Ridge Regression, and Lasso Regression, the baseline Linear Regression model was selected as the final model.
#
# Although Ridge and Lasso introduce regularization to reduce overfitting, they did not improve performance compared to the baseline Linear Regression model. The baseline Linear Regression model achieved the lowest cross-validation Mean Absolute Error (MAE), indicating that it generalized best to unseen data.
#
# This suggests that the dataset does not suffer significantly from overfitting or multicollinearity that would require regularization. It also suggests that feature engineering and hyperparameter tuning is not necessary, and in the scope of this analysis, in fact proved sub-optimal.

# %% [markdown]
# ### 5.2 Visualizations (5 points)
#
# Graphics should be made as screenshots and dragged into the Markdown cell. Do NOT add code cells to create graphics. Each visualization must be clearly labeled and explained in the text.
#
# Include:
# - relevant plots with titles and labels
# - explanation of what each plot shows
# - why each visualization matters
#
# **5.2 Answer:**
# As detailed in Milestone 2, when cross-validating all models (Linear, Ridge, and Lasso regression), the baseline linear regression model without any hyperparameter tuning performed the best. Our metrics for evaluation focused on the cross-validated MAE. The CV MAE and Standard Deviation CV MAE of all three baseline models are detailed in the image below:
#
# ![image.png](attachment:image.png)
#
# As shown above, all three baseline models have a very similar degree of performance. What's key, however, is the marginally lower MAE of the linear regression model. As we explored hyperparameter tuning and feature engineering, linear regression remained the clear winner:
#
# ![image-2.png](attachment:image-2.png)
#
#
# Interestingly, the CV MAE of the feature-engineered, hyperamater-tuned linear regression model ended up being higher than the baseline model. Even though linear regression was the consistent winner throughout our attempts to fine-tune the model, the baseline linear regression model still proved to be the most optimal. This indicates that the Zillow housing dataset is reliant on all of the included features: for the purpose of predicting housing prices, all features included in the original dataset clearly are deterministic for the price of a home.
#
# As we have learned this semester and last semester, data scientists often favor lean models for the purpose of accurate predictions. But it's crucial to remember that models are only as good as the data powering them allows them to be. Because the linear regression model consistently outperformed all other models, it's reasonable to conclude that teh Zillow housing dataset already has critical features that should not be excluded from a predictive model, and that simple linear regression is sufficient to predict the price of a house.

# %% [markdown]
# ### 5.3 Error Analysis (5 points)
#
# Include:
# - patterns in residuals or prediction errors
# - overprediction or underprediction
# - outliers or unusual observations
# - anything surprising or worth improving
#
# **5.3 Answer:**
# After training the final Linear Regression model and evaluating it on the held-out test set, the results indicate that the model generalizes well to unseen data. The test error is consistent with the cross-validation performance observed earlier, suggesting that the model is neither significantly overfitting nor underfitting. This alignment between validation and test performance supports the decision to select Linear Regression as the final model.
#
# An analysis of prediction errors shows that most predictions are reasonably close to the true values, with errors distributed around zero rather than exhibiting a strong systematic bias. However, there is some spread in the errors, particularly for observations with more extreme target values. This suggests that while the model captures the overall linear relationship in the data, it may struggle to fully account for more complex or nonlinear patterns present in certain regions of the feature space.
#
# Additionally, the presence of larger errors for some data points may indicate the influence of outliers or features that are not well explained by a purely linear model. Since Linear Regression assumes a linear relationship between features and the target, any underlying nonlinear interactions or omitted variables could contribute to these discrepancies. Despite this, the overall magnitude and distribution of errors remain acceptable for the scope of this analysis.
#
# In summary, the error analysis confirms that the Linear Regression model provides a strong balance between simplicity and predictive performance. While there is some room for improvement—particularly in handling extreme values or subtle nonlinearities—the model performs consistently and reliably, making it an appropriate final choice for this dataset.

# %% [markdown]
# ## 6. Conclusion [4 pts]
#
# Summarize your findings and implications.
#
# Include all the following:
#
# - Clearly state your main findings and how they address your original objectives
# - Highlight any business or practical implications of your findings
# - Discuss the limitations and constraints of your analysis clearly and transparently
# - Suggest potential improvements or future directions
# - Conclude with a final recommendation addressing the business objective
#
# **6.1 Answer:**
# The goal of this project was to develop a reliable model for predicting housing prices using the Zillow dataset and to understand which factors most strongly influence property value. Our group analysis showed that machine learning models like random forest can effectively capture the complex, nonlinear relationships present in housing data. These models outperformed simpler baseline approaches, confirming that housing prices are influenced by multiple interacting variables, not just straightforward linear trends.
#
# Some of our key findings showed that features related to property size, location, and tax metrics were some of the most important predictors of housing prices. Transforming skewed variables, including our target variable, significantly improved model stability and predictive performance. Our results directly relate to our objective by both producing accurate predictions and identifying the most influential drivers of housing value.
#
# From a business perspective, these findings have clear practical value. Accurate price prediction models can support real estate platforms, investors, and buyers in making more informed decisions. For example, automated valuation models can assist in pricing proerties competitively, identify undervalued houses, and improve market transparency.
#
# There are several limiations we ran into that should be acknowledged. The dataset contained a lot of missing values, which required median imputation and may have introduced bias. The model also does not fully capytre external factors such as market trends, economic conditions, or neighborhood dynamics that may influence prices. Our analysis was limited to the features available in the dataset, which could not represent all relevant real world variables.
#
# Future improvements could include incorporating additional data sources, such as economic status, geographic data, or time-series market trends, to improve predictive accuracy. More advanced models like gradient boosting or neural networks could also be explored to improve performance.
#
# In conclusion, we recommend the use of ensemble based machine learning models, such as random forests, for housing price prediction in the Zillow dataset. These models provide a good balance between accuracy and stability while giving key insights into drivers of property value. Implementing these models in a real world setting could significantly improve pricing strategies, investment designs, and overall market analysis.
